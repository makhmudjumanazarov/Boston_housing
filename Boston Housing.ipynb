# %% [markdown]
# **Boston Housing price regression dataset**

# %% [markdown]
# ## <span id="1"></span> 1. *Overview*

# %% [markdown]
# Columns:
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per \$10,000
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in \$1000's

# %% [markdown]
# ## <span id="2"></span> 2. Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## <span id="3"></span> 3. Load Dataset

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.boston_housing.load_data(
    path="boston_housing.npz", test_split=0.2, seed=113
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %% [markdown]
# ## <span id="4"></span> 4. Normalize Dataset

# %%
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)
x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

# %%
model = Sequential()

model.add(Dense(128,activation  = 'relu',input_dim =13))
model.add(Dense(64,activation  = 'relu'))
model.add(Dense(32,activation  = 'relu'))
model.add(Dense(16,activation  = 'relu'))
model.add(Dense(1))
model.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
model.fit(x=x_train,y=y_train, validation_data=(x_test,y_test),epochs=200, batch_size = 32)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 29ms/step - loss: 578.1112 - val_loss: 587.8839
# Epoch 2/200
# 13/13 [==============================] - 0s 7ms/step - loss: 533.9583 - val_loss: 519.5782
# Epoch 3/200
# 13/13 [==============================] - 0s 8ms/step - loss: 438.2827 - val_loss: 370.0666
# Epoch 4/200
# 13/13 [==============================] - 0s 8ms/step - loss: 250.2788 - val_loss: 144.3626
# Epoch 5/200
# 13/13 [==============================] - 0s 7ms/step - loss: 104.0197 - val_loss: 93.4416
# Epoch 6/200
# 13/13 [==============================] - 0s 7ms/step - loss: 67.2750 - val_loss: 53.0514
# Epoch 7/200
# 13/13 [==============================] - 0s 9ms/step - loss: 40.9167 - val_loss: 36.9915
# Epoch 8/200
# 13/13 [==============================] - 0s 8ms/step - loss: 29.4398 - val_loss: 30.6331
# Epoch 9/200
# 13/13 [==============================] - 0s 7ms/step - loss: 25.1614 - val_loss: 27.4765
# Epoch 10/200
# 13/13 [==============================] - 0s 6ms/step - loss: 22.4820 - val_loss: 24.8764
# Epoch 11/200
# 13/13 [==============================] - 0s 7ms/step - loss: 20.5341 - val_loss: 24.6968
# Epoch 12/200
# 13/13 [==============================] - 0s 7ms/step - loss: 18.7465 - val_loss: 24.3531
# Epoch 13/200
# 13/13 [==============================] - 0s 7ms/step - loss: 17.0844 - val_loss: 23.8709
# Epoch 14/200
# 13/13 [==============================] - 0s 8ms/step - loss: 15.9005 - val_loss: 22.8195
# Epoch 15/200
# 13/13 [==============================] - 0s 7ms/step - loss: 14.6050 - val_loss: 23.4621
# Epoch 16/200
# 13/13 [==============================] - 0s 8ms/step - loss: 13.8057 - val_loss: 22.9994
# Epoch 17/200
# 13/13 [==============================] - 0s 8ms/step - loss: 12.9876 - val_loss: 23.0970
# Epoch 18/200
# 13/13 [==============================] - 0s 9ms/step - loss: 12.2405 - val_loss: 23.1271
# Epoch 19/200
# 13/13 [==============================] - 0s 8ms/step - loss: 11.8466 - val_loss: 23.0912
# Epoch 20/200
# 13/13 [==============================] - 0s 10ms/step - loss: 11.5145 - val_loss: 23.0558
# Epoch 21/200
# 13/13 [==============================] - 0s 7ms/step - loss: 11.2811 - val_loss: 23.7598
# Epoch 22/200
# 13/13 [==============================] - 0s 8ms/step - loss: 10.9656 - val_loss: 22.8367
# Epoch 23/200
# 13/13 [==============================] - 0s 5ms/step - loss: 10.5316 - val_loss: 23.4243
# Epoch 24/200
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2081 - val_loss: 23.3124
# Epoch 25/200
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9814 - val_loss: 23.6123
# Epoch 26/200
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8928 - val_loss: 22.9995
# Epoch 27/200
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7266 - val_loss: 22.9647
# Epoch 28/200
# 13/13 [==============================] - 0s 5ms/step - loss: 9.4943 - val_loss: 22.3198
# Epoch 29/200
# 13/13 [==============================] - 0s 5ms/step - loss: 9.3285 - val_loss: 23.7295
# Epoch 30/200
# 13/13 [==============================] - 0s 5ms/step - loss: 9.2782 - val_loss: 23.3980
# Epoch 31/200
# 13/13 [==============================] - 0s 6ms/step - loss: 9.0372 - val_loss: 22.6741
# Epoch 32/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8669 - val_loss: 23.6567
# Epoch 33/200
# 13/13 [==============================] - 0s 7ms/step - loss: 8.9532 - val_loss: 21.9436
# Epoch 34/200
# 13/13 [==============================] - 0s 5ms/step - loss: 8.8208 - val_loss: 22.1576
# Epoch 35/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8620 - val_loss: 22.4059
# Epoch 36/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.4799 - val_loss: 22.6380
# Epoch 37/200
# 13/13 [==============================] - 0s 5ms/step - loss: 8.3677 - val_loss: 22.4823
# Epoch 38/200
# 13/13 [==============================] - 0s 7ms/step - loss: 8.2948 - val_loss: 22.5098
# Epoch 39/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.4315 - val_loss: 21.3791
# Epoch 40/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.2289 - val_loss: 22.7917
# Epoch 41/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.1119 - val_loss: 21.4457
# Epoch 42/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.9242 - val_loss: 23.1566
# Epoch 43/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.7860 - val_loss: 21.7919
# Epoch 44/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.6359 - val_loss: 21.5120
# Epoch 45/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.5848 - val_loss: 21.4327
# Epoch 46/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.5762 - val_loss: 21.5748
# Epoch 47/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.4334 - val_loss: 21.4252
# Epoch 48/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.4044 - val_loss: 21.2665
# Epoch 49/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.3904 - val_loss: 20.8902
# Epoch 50/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.4523 - val_loss: 21.1039
# Epoch 51/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.1834 - val_loss: 20.5376
# Epoch 52/200
# 13/13 [==============================] - 0s 6ms/step - loss: 7.1368 - val_loss: 20.3512
# Epoch 53/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.2307 - val_loss: 21.2982
# Epoch 54/200
# 13/13 [==============================] - 0s 5ms/step - loss: 7.4107 - val_loss: 20.1446
# Epoch 55/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.8624 - val_loss: 21.2459
# Epoch 56/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8381 - val_loss: 20.3689
# Epoch 57/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8281 - val_loss: 20.7111
# Epoch 58/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8930 - val_loss: 20.9724
# Epoch 59/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.9846 - val_loss: 18.9889
# Epoch 60/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.6779 - val_loss: 19.7900
# Epoch 61/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.5174 - val_loss: 19.6775
# Epoch 62/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4277 - val_loss: 20.2051
# Epoch 63/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.4561 - val_loss: 18.8811
# Epoch 64/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4580 - val_loss: 18.9041
# Epoch 65/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.3145 - val_loss: 19.1214
# Epoch 66/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0758 - val_loss: 18.4339
# Epoch 67/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.2126 - val_loss: 20.3825
# Epoch 68/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.0726 - val_loss: 18.5896
# Epoch 69/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.2456 - val_loss: 19.0708
# Epoch 70/200
# 13/13 [==============================] - 0s 5ms/step - loss: 6.1094 - val_loss: 18.5929
# Epoch 71/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.8002 - val_loss: 18.3497
# Epoch 72/200
# 13/13 [==============================] - 0s 6ms/step - loss: 5.9290 - val_loss: 18.0559
# Epoch 73/200
# 13/13 [==============================] - 0s 7ms/step - loss: 5.7166 - val_loss: 17.8773
# Epoch 74/200
# 13/13 [==============================] - 0s 6ms/step - loss: 5.5906 - val_loss: 19.0365
# Epoch 75/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.6561 - val_loss: 18.0341
# Epoch 76/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.8140 - val_loss: 18.3650
# Epoch 77/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.6412 - val_loss: 18.2225
# Epoch 78/200
# 13/13 [==============================] - 0s 6ms/step - loss: 5.8195 - val_loss: 17.2434
# Epoch 79/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.9729 - val_loss: 18.3183
# Epoch 80/200
# 13/13 [==============================] - 0s 7ms/step - loss: 6.2240 - val_loss: 18.6134
# Epoch 81/200
# 13/13 [==============================] - 0s 7ms/step - loss: 5.5049 - val_loss: 17.0249
# Epoch 82/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.2866 - val_loss: 17.4633
# Epoch 83/200
# 13/13 [==============================] - 0s 6ms/step - loss: 5.1375 - val_loss: 17.4417
# Epoch 84/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.1518 - val_loss: 17.6479
# Epoch 85/200
# 13/13 [==============================] - 0s 6ms/step - loss: 5.0455 - val_loss: 17.5517
# Epoch 86/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.1899 - val_loss: 16.2642
# Epoch 87/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.9721 - val_loss: 17.3940
# Epoch 88/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.9315 - val_loss: 17.3534
# Epoch 89/200
# 13/13 [==============================] - 0s 5ms/step - loss: 5.0183 - val_loss: 16.2877
# Epoch 90/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7514 - val_loss: 16.2368
# Epoch 91/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7354 - val_loss: 16.9933
# Epoch 92/200
# 13/13 [==============================] - 0s 7ms/step - loss: 4.7082 - val_loss: 16.1828
# Epoch 93/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.5894 - val_loss: 17.2110
# Epoch 94/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7192 - val_loss: 16.1514
# Epoch 95/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.8716 - val_loss: 16.7341
# Epoch 96/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.6675 - val_loss: 16.1646
# Epoch 97/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.5244 - val_loss: 15.7749
# Epoch 98/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.6651 - val_loss: 15.9220
# Epoch 99/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.5105 - val_loss: 16.1382
# Epoch 100/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.3977 - val_loss: 15.7965
# Epoch 101/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.2181 - val_loss: 16.3696
# Epoch 102/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.3434 - val_loss: 14.9029
# Epoch 103/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.2715 - val_loss: 15.1034
# Epoch 104/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.2769 - val_loss: 15.2440
# Epoch 105/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.1638 - val_loss: 15.0338
# Epoch 106/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.0846 - val_loss: 14.3969
# Epoch 107/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.2891 - val_loss: 15.3367
# Epoch 108/200
# 13/13 [==============================] - 0s 7ms/step - loss: 4.6302 - val_loss: 16.1494
# Epoch 109/200
# 13/13 [==============================] - 0s 5ms/step - loss: 4.2447 - val_loss: 14.8985
# Epoch 110/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.9263 - val_loss: 14.8495
# Epoch 111/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.9505 - val_loss: 14.2343
# Epoch 112/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.0125 - val_loss: 14.9809
# Epoch 113/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.8813 - val_loss: 15.1055
# Epoch 114/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.9966 - val_loss: 14.0753
# Epoch 115/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.9646 - val_loss: 14.5054
# Epoch 116/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.8184 - val_loss: 14.5796
# Epoch 117/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.9732 - val_loss: 14.3745
# Epoch 118/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.9563 - val_loss: 14.8686
# Epoch 119/200
# 13/13 [==============================] - 0s 7ms/step - loss: 3.8415 - val_loss: 14.0382
# Epoch 120/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.6998 - val_loss: 15.6119
# Epoch 121/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.8931 - val_loss: 13.7852
# Epoch 122/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.6212 - val_loss: 14.0888
# Epoch 123/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.4935 - val_loss: 13.6911
# Epoch 124/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.5278 - val_loss: 13.3573
# Epoch 125/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.5794 - val_loss: 13.8479
# Epoch 126/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.5056 - val_loss: 15.1795
# Epoch 127/200
# 13/13 [==============================] - 0s 4ms/step - loss: 3.5437 - val_loss: 13.4446
# Epoch 128/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.6230 - val_loss: 13.6468
# Epoch 129/200
# 13/13 [==============================] - 0s 4ms/step - loss: 3.4476 - val_loss: 13.9345
# Epoch 130/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.4723 - val_loss: 14.2844
# Epoch 131/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.2622 - val_loss: 14.5110
# Epoch 132/200
# 13/13 [==============================] - 0s 6ms/step - loss: 4.1861 - val_loss: 13.5802
# Epoch 133/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.5996 - val_loss: 14.2680
# Epoch 134/200
# 13/13 [==============================] - 0s 7ms/step - loss: 3.4383 - val_loss: 14.0592
# Epoch 135/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.5133 - val_loss: 13.3357
# Epoch 136/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.5402 - val_loss: 13.2330
# Epoch 137/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.3661 - val_loss: 13.3087
# Epoch 138/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.2799 - val_loss: 13.9006
# Epoch 139/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.1165 - val_loss: 13.3938
# Epoch 140/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.1623 - val_loss: 13.0751
# Epoch 141/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.3869 - val_loss: 13.8037
# Epoch 142/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.0705 - val_loss: 13.6200
# Epoch 143/200
# 13/13 [==============================] - 0s 6ms/step - loss: 3.0042 - val_loss: 13.5008
# Epoch 144/200
# 13/13 [==============================] - 0s 5ms/step - loss: 3.0265 - val_loss: 13.3529
# Epoch 145/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.9580 - val_loss: 12.9811
# Epoch 146/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.8904 - val_loss: 13.6463
# Epoch 147/200
# 13/13 [==============================] - 0s 7ms/step - loss: 3.0324 - val_loss: 13.3957
# Epoch 148/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.9763 - val_loss: 13.5528
# Epoch 149/200
# 13/13 [==============================] - 0s 5ms/step - loss: 2.8841 - val_loss: 12.8607
# Epoch 150/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.9779 - val_loss: 12.9759
# Epoch 151/200
# 13/13 [==============================] - 0s 7ms/step - loss: 3.1451 - val_loss: 13.4810
# Epoch 152/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.8269 - val_loss: 13.9078
# Epoch 153/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7741 - val_loss: 13.0997
# Epoch 154/200
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7371 - val_loss: 13.0887
# Epoch 155/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7987 - val_loss: 12.9478
# Epoch 156/200
# 13/13 [==============================] - 0s 9ms/step - loss: 2.9471 - val_loss: 12.8409
# Epoch 157/200
# 13/13 [==============================] - 0s 9ms/step - loss: 2.8589 - val_loss: 13.6658
# Epoch 158/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7004 - val_loss: 13.0730
# Epoch 159/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.5959 - val_loss: 13.5909
# Epoch 160/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7906 - val_loss: 12.8782
# Epoch 161/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.5709 - val_loss: 12.6224
# Epoch 162/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.5066 - val_loss: 13.0758
# Epoch 163/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.5391 - val_loss: 12.5587
# Epoch 164/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.4781 - val_loss: 12.4738
# Epoch 165/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.4821 - val_loss: 12.3447
# Epoch 166/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7027 - val_loss: 13.8164
# Epoch 167/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.9746 - val_loss: 13.7436
# Epoch 168/200
# 13/13 [==============================] - 0s 9ms/step - loss: 2.6904 - val_loss: 12.6120
# Epoch 169/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.6511 - val_loss: 12.3019
# Epoch 170/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.5319 - val_loss: 12.3258
# Epoch 171/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.5641 - val_loss: 12.9098
# Epoch 172/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3648 - val_loss: 12.0298
# Epoch 173/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3840 - val_loss: 12.8317
# Epoch 174/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3221 - val_loss: 12.6057
# Epoch 175/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.4096 - val_loss: 13.3214
# Epoch 176/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.4996 - val_loss: 13.3943
# Epoch 177/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3791 - val_loss: 12.7069
# Epoch 178/200
# 13/13 [==============================] - 0s 10ms/step - loss: 2.3300 - val_loss: 12.4906
# Epoch 179/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1853 - val_loss: 11.7583
# Epoch 180/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1943 - val_loss: 12.4930
# Epoch 181/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1859 - val_loss: 13.1403
# Epoch 182/200
# 13/13 [==============================] - 0s 9ms/step - loss: 2.3477 - val_loss: 11.8385
# Epoch 183/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2577 - val_loss: 12.4482
# Epoch 184/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2174 - val_loss: 12.2036
# Epoch 185/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1421 - val_loss: 12.0229
# Epoch 186/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1732 - val_loss: 12.0757
# Epoch 187/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.1140 - val_loss: 12.0047
# Epoch 188/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0589 - val_loss: 13.2803
# Epoch 189/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.2711 - val_loss: 12.2360
# Epoch 190/200
# 13/13 [==============================] - 0s 7ms/step - loss: 2.1578 - val_loss: 12.4843
# Epoch 191/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0654 - val_loss: 13.0262
# Epoch 192/200
# 13/13 [==============================] - 0s 6ms/step - loss: 2.4095 - val_loss: 13.7275
# Epoch 193/200
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0400 - val_loss: 11.7661
# Epoch 194/200
# 13/13 [==============================] - 0s 9ms/step - loss: 1.9791 - val_loss: 12.2268
# Epoch 195/200
# 13/13 [==============================] - 0s 7ms/step - loss: 1.9613 - val_loss: 11.4633
# Epoch 196/200
# 13/13 [==============================] - 0s 8ms/step - loss: 1.9744 - val_loss: 11.8479
# Epoch 197/200
# 13/13 [==============================] - 0s 9ms/step - loss: 1.9081 - val_loss: 12.0992
# Epoch 198/200
# 13/13 [==============================] - 0s 9ms/step - loss: 1.9015 - val_loss: 11.9578
# Epoch 199/200
# 13/13 [==============================] - 0s 6ms/step - loss: 1.9231 - val_loss: 12.0105
# Epoch 200/200
# 13/13 [==============================] - 0s 5ms/step - loss: 1.7522 - val_loss: 11.7867

# %%
loss = model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7867

# %%
model.save('/content/drive/MyDrive/Machine Learning Specialization/Boston_housing/model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
model_load = tf.keras.models.load_model('/content/drive/MyDrive/Machine Learning Specialization/Boston_housing/model')

# %%
model_load.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7867
# 11.786715507507324

# %%
model_load.predict(x_test[0:1])
# Out:
# 1/1 [==============================] - 0s 103ms/step
# array([[9.22364]], dtype=float32)

# %%
data = tf.keras.datasets.boston_housing.load_data(
    path="boston_housing.npz"
)

# %%
import pandas as pd

# %%
df_train = pd.DataFrame(data[0][0], columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

# %%
df_train_target = pd.DataFrame(data[0][1], columns=['MEDV'])

# %%
df_test = pd.DataFrame(data[1][0], columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

# %%
df_test_target  = pd.DataFrame(data[1][1], columns = ['MEDV'])

# %%
df1 = pd.concat([df_train, df_test], axis = 0, ignore_index=True)

# %%
target = pd.concat([df_train_target, df_test_target], axis = 0, ignore_index = True)

# %%
df = pd.concat([df1, target], axis = 1)

# %%
df.to_csv('/content/drive/MyDrive/Machine Learning Specialization/Boston_housing/boston_housing.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize = (20, 10))
index = 0
ax = ax.flatten()
for a, b in df.items():
  sns.boxplot(y = a, data = df, ax = ax[index])
  index = index + 1
fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# Columns like CRIM, ZN, RM, B seems to have outliers. Let's see the outliers percentage in every column.

# %%
for a, b in df.items():
  q1 = b.quantile(0.25)
  q3 = b.quantile(0.75)
  diff = q3 - q1
  v_col = b[(b <= q1 - 1.5 * diff) | (b >= q3 + 1.5 * diff)]
  perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
  print("Column %s outliers = %.2f%%" % (a, perc))
# Out:
# Column CRIM outliers = 13.04%
# Column ZN outliers = 13.44%
# Column INDUS outliers = 0.00%
# Column CHAS outliers = 100.00%
# Column NOX outliers = 0.00%
# Column RM outliers = 5.93%
# Column AGE outliers = 0.00%
# Column DIS outliers = 0.99%
# Column RAD outliers = 0.00%
# Column TAX outliers = 0.00%
# Column PTRATIO outliers = 2.96%
# Column B outliers = 15.22%
# Column LSTAT outliers = 1.38%
# Column MEDV outliers = 7.91%

# %% [markdown]
# Let's remove MEDV outliers (MEDV = 50.0) before plotting more distributions

# %%
df = df[~(df['MEDV'] >= 50.0)]
print(np.shape(df))
# Out:
# (490, 14)

# %%
df['MEDV'].isnull().sum()
# Out:
# 0

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1    0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2    0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 3    3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 4    0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 485  0.66351  20.0   3.97   0.0  0.647  7.333  100.0  1.8946   5.0  264.0
# 486  3.47428   0.0  18.10   1.0  0.718  8.780   82.9  1.9047  24.0  666.0
# 487  0.07896   0.0  12.83   0.0  0.437  6.273    6.0  4.2515   5.0  398.0
# 488  0.35809   0.0   6.20   1.0  0.507  6.951   88.5  2.8617   8.0  307.0
# 489  2.92400   0.0  19.58   0.0  0.605  6.101   93.0  2.2834   5.0  403.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       21.0  396.90  18.72  15.2
# 1       14.7  395.38   3.11  42.3
# 2       20.2  396.90   8.01  21.1
# 3       20.2  391.43  14.65  17.7
# 4       19.6  391.13  11.74  18.5
# ..       ...     ...    ...   ...
# 485     13.0  383.29   7.79  36.0
# 486     20.2  354.55   5.29  21.9
# 487     18.7  394.92   6.78  24.1
# 488     17.4  391.70   9.71  26.7
# 489     14.7  240.16   9.81  25.0
#
# [490 rows x 14 columns]

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
# Out:
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# <ipython-input-157-8490618771fd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])

# %% [markdown]
# The histogram also shows that columns CRIM, ZN, B has highly skewed distributions. Also MEDV looks to have a normal distribution (the predictions) and other colums seem to have norma or bimodel ditribution of data except CHAS (which is a discrete variable).

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr().abs(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From correlation matrix, we see TAX and RAD are highly correlated features. The columns LSTAT, INDUS, RM, TAX, NOX, PTRAIO has a correlation score above 0.5 with MEDV which is a good indication of using as predictors.

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX', 'DIS', 'AGE']
x = df.loc[:,column_sels]
y = df['MEDV']
x = pd.DataFrame(data=min_max_scaler.fit_transform(x), columns=column_sels)
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# So with these analsis, we may try predict MEDV with 'LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX', 'DIS', 'AGE' features. Let's try to remove the skewness of the data trough log transformation.

# %%
y =  np.log1p(y)

# %%
for col in x.columns: 
    if np.abs(x[col].skew()) > 0.3:
        x[col] = np.log1p(x[col])

# %%
y.describe()
# Out:
# count    490.000000
# mean      21.635918
# std        7.865301
# min        5.000000
# 25%       16.700000
# 50%       20.900000
# 75%       24.675000
# max       48.800000
# Name: MEDV, dtype: float64

# %%
y.describe()
# Out:
# count    490.000000
# mean       3.057799
# std        0.361161
# min        1.791759
# 25%        2.873565
# 50%        3.086487
# 75%        3.245516
# max        3.908015
# Name: MEDV, dtype: float64

# %%
x.describe()
# Out:
#             LSTAT       INDUS         NOX     PTRATIO          RM         TAX  \
# count  490.000000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean     0.304085    0.384190    0.348369    0.629787    0.514365    0.421760
# std      0.196810    0.252641    0.240098    0.224519    0.125148    0.320735
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.149139    0.164815    0.131687    0.510638    0.444530    0.177958
# 50%      0.269380    0.331481    0.314815    0.691489    0.502778    0.272901
# 75%      0.420603    0.642963    0.491770    0.808511    0.578080    0.914122
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               DIS         AGE
# count  490.000000  490.000000
# mean     0.245463    0.673316
# std      0.191997    0.290060
# min      0.000000    0.000000
# 25%      0.088635    0.428939
# 50%      0.194631    0.761071
# 75%      0.371045    0.936921
# max      1.000000    1.000000

# %%
x.describe()
# Out:
#             LSTAT       INDUS         NOX     PTRATIO          RM         TAX  \
# count  490.000000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean     0.254804    0.308681    0.283883    0.477944    0.514365    0.328055
# std      0.144464    0.181035    0.171482    0.149142    0.125148    0.215139
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.139013    0.152562    0.123710    0.412532    0.444530    0.163782
# 50%      0.238529    0.286292    0.273696    0.525609    0.502778    0.241298
# 75%      0.351081    0.496501    0.399963    0.592504    0.578080    0.649259
# max      0.693147    0.693147    0.693147    0.693147    1.000000    0.693147
#
#               DIS         AGE
# count  490.000000  490.000000
# mean     0.208484    0.498227
# std      0.146131    0.187101
# min      0.000000    0.000000
# 25%      0.084924    0.356931
# 50%      0.177838    0.565922
# 75%      0.315573    0.661099
# max      0.693147    0.693147

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import numpy as np

l_regression = linear_model.LinearRegression()
kf = KFold(n_splits=10)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
scores = cross_val_score(l_regression, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))

scores_map = {}
scores_map['LinearRegression'] = scores
l_ridge = linear_model.Ridge()
scores = cross_val_score(l_ridge, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['Ridge'] = scores
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))

# Lets try polinomial regression with L2 with degree for the best fit
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
#for degree in range(2, 6):
#    model = make_pipeline(PolynomialFeatures(degree=degree), linear_model.Ridge())
#    scores = cross_val_score(model, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
#    print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
model = make_pipeline(PolynomialFeatures(degree=3), linear_model.Ridge())
scores = cross_val_score(model, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['PolyRidge'] = scores
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# MSE: -0.03 (+/- 0.01)
# MSE: -0.03 (+/- 0.01)
# MSE: -0.02 (+/- 0.01)

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
grid_sv = GridSearchCV(svr_rbf, cv=kf, param_grid={"C": [1e0, 1e1, 1e2, 1e3], "gamma": np.logspace(-2, 2, 5)}, scoring='neg_mean_squared_error')
grid_sv.fit(x_scaled, y)
print("Best classifier :", grid_sv.best_estimator_)
scores = cross_val_score(svr_rbf, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['SVR'] = scores
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# Best classifier : SVR(C=10.0, gamma=1.0)
# MSE: -0.02 (+/- 0.01)

# %%
from sklearn.tree import DecisionTreeRegressor

desc_tr = DecisionTreeRegressor(max_depth=5)
grid_sv = GridSearchCV(desc_tr, cv=kf, param_grid={"max_depth" : [1, 2, 3, 4, 5, 6, 7]}, scoring='neg_mean_squared_error')
grid_sv.fit(x_scaled, y)
print("Best classifier :", grid_sv.best_estimator_)
scores = cross_val_score(desc_tr, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['DecisionTreeRegressor'] = scores
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# Best classifier : DecisionTreeRegressor(max_depth=5)
# MSE: -0.03 (+/- 0.01)

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=7)
scores = cross_val_score(knn, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['KNeighborsRegressor'] = scores
#grid_sv = GridSearchCV(knn, cv=kf, param_grid={"n_neighbors" : [2, 3, 4, 5, 6, 7]}, scoring='neg_mean_squared_error')
#grid_sv.fit(x_scaled, y)
#print("Best classifier :", grid_sv.best_estimator_)
print("KNN Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# KNN Accuracy: -0.02 (+/- 0.01)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(alpha=0.9,learning_rate=0.05, max_depth=2, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=30)
param_grid={'n_estimators':[100, 200], 'learning_rate': [0.1,0.05,0.02], 'max_depth':[2, 4,6], 'min_samples_leaf':[3,5,9]}
grid_sv = GridSearchCV(gbr, cv=kf, param_grid=param_grid, scoring='neg_mean_squared_error')
grid_sv.fit(x_scaled, y)
print("Best classifier :", grid_sv.best_estimator_)
scores = cross_val_score(gbr, x_scaled, y, cv=kf, scoring='neg_mean_squared_error')
scores_map['GradientBoostingRegressor'] = scores
print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# Best classifier : GradientBoostingRegressor(learning_rate=0.05, max_depth=2, min_samples_leaf=9,
#                           n_estimators=200, random_state=30)
# MSE: -0.02 (+/- 0.01)

# %%
plt.figure(figsize=(20, 10))
scores_map = pd.DataFrame(scores_map)
sns.boxplot(data=scores_map)
# Out:
# <Axes: >
