# %%
import tensorflow as tf
import streamlit as st
from tensorflow.keras.models import load_model

# %%
# !pip install streamlit

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.boston_housing.load_data(
    path="boston_housing.npz", test_split=0.2, seed=113
)

# %%
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)
x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

# %%
model_load = tf.keras.models.load_model('/content/drive/MyDrive/Machine Learning Specialization/Boston_housing/model')

# %%
model_load.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7867
# 11.786715507507324

# %%
model_load.predict(x_test[0:1])
# Out:
# 1/1 [==============================] - 0s 112ms/step
# array([[9.22364]], dtype=float32)

# %%
st.write("Enter values for your house")
data = [0 for i in range(13)]
data[0] = st.number_input('CRIM - per capita crime rate by town', step=0.1)
# Out:
# WARNING:root:
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.9/dist-packages/ipykernel_launcher.py [ARGUMENTS]
# 2023-03-21 10:48:01.993
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.9/dist-packages/ipykernel_launcher.py [ARGUMENTS]
